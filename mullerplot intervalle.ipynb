# %%
from lgca import get_lgca
from lgca.helpers import *
import numpy as np
import matplotlib.pyplot as plt
import time

name = '18090_2props_t id='
props = np.load('saved_data/' + name +'.npy')
# tend = len(propst)
# time = range(0, tend)
# maxlab = len(propst[0]['num_off'])-1
# lgca = get_lgca(ib=True, geometry='lin', interaction='inheritance', bc='reflecting',\
#                density = 1, dims = 1, r_b = 0.5, variation = False, restchannels = 2 ,r_d = 0.02)
# lgca.timeevo_until_hom(record = True)
# props = lgca.props_t
# print('Zeitschritte bis Homogenität ', len(props) - 1)
# print(props)
# print('maxlab ist ', maxlab)

# %%
# %matplotlib notebook
# tend = len(props)
# maxlab = len(props[0]['num_off']) - 1
# int_range = 10
# fig = plt.subplot()

# val = np.zeros((maxlab, tend))
# for t in range(0, tend):
#     for lab in range(0, maxlab):
#         val[lab, t] = props[t]['num_off'][lab + 1]


# int_num = ((tend - 1) // int_range + 1)
# # xrange = range(0, int_num+2)
# xrange = np.zeros(int_num + 2)

# mean_val = np.zeros((maxlab, int_num)) + -999
# for i in range(0, int_num - 1):
#     xrange[i+1] = i + 0.5
#     #     print(i*li, (i+1)*li-1)
#     for lab in range(0, maxlab):
#         mean_val[lab, i] = np.sum(val[lab, i * int_range:(i + 1) * int_range]) / int_range
# print('x', xrange)
# xrange[-2] = int_num-0.5
# xrange[-1] = int_num
# print('x', xrange)
# for lab in range(0, maxlab):
#     mean_val[lab, int_num - 1] =\
#         np.sum(val[lab, (int_num - 1) * int_range:]) / (tend - (int_num - 1) * int_range)
# pop = np.zeros((maxlab, int_num+2)) + -777
# pop[:,0] = val[:,0]
# pop[:, 1:-1] = mean_val
# pop[:,-1] = val[:,-1]
# plt.xlabel('intervalls')

# popdic = {str(i): pop[i] for i in range(0, maxlab)}
# data = pd.DataFrame(popdic, index=xrange)
# data_perc = data.divide(data.sum(axis=1), axis=0)

# plt.ylabel(' frequency of families')

# # plot einstellungen
# plt.xlim(0, xrange[-1])
# plt.ylim(0, 1)
# if xrange[-1] <= 15:
#     plt.xticks(np.arange(0, xrange[-1], 1))
# elif xrange[-1] <= 100:
#     plt.xticks(np.arange(0, xrange[-1], 5))
# elif xrange[-1] >= 1000:
#     plt.xticks(np.arange(0, xrange[-1], 500))
# elif xrange[-1] >= 100:
#     plt.xticks(np.arange(0, xrange[-1], 50))


# plt.stackplot(xrange, *[data_perc[str(f)] for f in range(0, maxlab)],\
#               labels=list(range(0, maxlab)))
# plt.show()

# %%
# import numpy as np
# xrange = range(0, 5+2)
# r = np.zeros(7)
# print(r)
# for i in range(0, len(xrange)):
#     print(xrange[i])
# for i in range(1, len(r)):
#     r[i] = i-0.5
#     print(r[i])
# r[-1] = 5
# print(r)

# %%
# von = 30
# # bis = 9
# li = 10
# for lab in range(0, maxlab):
# #     print('sum', np.sum(val[lab, von:(von+li)]))
#     print('mean', np.sum(val[lab, von:(von+li)])/li)
# for lab in range(0, maxlab):
# #     print('sum', np.sum(val[lab, von:(von+li)]))
#     print('last', np.sum(val[lab, 40:41])/(1))
# x = range(0,5)
# print(x[-1])

# %%
# %matplotlib notebook
mullerplot(props)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
mullerplot_extended(props, int_range=1)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
mullerplot_extended(props, int_range=100, zusatz=True)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
mullerplot_extended(props, int_range=100)
# Out:
# <img src="data:image/png;base64,..." width="640">
