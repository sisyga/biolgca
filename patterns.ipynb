# %%
from test_hex import run_simulation

# %%
run_simulation(interaction="contact_guidance")
# Out:
# Progress: [####################] 100% Done...

# %%
run_simulation(interaction="ecm_guidance")
# Out:
# Progress: [####################] 100% Done...
