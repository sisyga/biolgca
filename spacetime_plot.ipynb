# %%
from lgca import get_lgca
from lgca.helpers import *
from lgca.analysis import *
import numpy as np
import matplotlib.pyplot as plt
import time

# %% [markdown]
# Daten einlesen:

# %%
variation = '82'
filename =  '06c0de0'
selection = '0'
path = 'saved_data/'
labels = np.load(path + variation + '_' + selection + '_'+ filename + '_labels.npy')
nodest = np.load(path + variation + '_' + selection + '_'+ filename +  '_nodest.npy')

# %% [markdown]
# Spacetimeplot:

# %%
beg = 5
end = None
name = variation + '_' + selection + '_'+ filename

spacetime_plot(nodes_t=nodest, labels=labels, save=True, tbeg=beg, tend=end, id=name, figsize=(20,70))
# Out:
# tmax, Knoten, rc 118 2 2
