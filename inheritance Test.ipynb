# %%
from lgca import get_lgca
from lgca.helpers import *
import numpy as np
import matplotlib.pyplot as plt
# from matplotlib import cm
# %matplotlib notebook

timesteps = 500
dim = 5
dens =  1

#rb = [0.02, 0.1, 0.3, 0.5, 0.7, 0.9, 1]
birthrate = 0.5
rc = 1
deathrate = 0.02
id = 0
r = 1

lgca= get_lgca(ib=True, geometry='lin', interaction='inheritance', r_int = r,\
               density = dens, dims = dim, r_b = birthrate, variation = False, restchannels = rc ,r_d = deathrate)

lgca.timeevo(timesteps, record=True)
# bar_stacked(lgca, save = False, id = id)
# ana_si(lgca, p = True, save = False, id = id)
#     save_data(lgca, id = id)
 #, figsize = (10,70)
# Out:
# standard deviation set to =  0.1
# Progress: [####################] 100% Done...

# %%
lgca.spatial_plot(cmap='tab20', figsize=(30,90))

# %%
ltotal = 15
rc=1
vc=2
np.arange(0, ltotal, rc+vc)
# Out:
# array([ 0,  3,  6,  9, 12])
